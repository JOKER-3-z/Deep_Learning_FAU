# %%
from pattern import Spectrum,Checker,Circle
s =Spectrum(255)
spec = s.draw()
s.show()

# %%
s = Checker(300, 10)
spec = s.draw()
s.show()

# %%
s = Circle(1024, 200, (512, 256))
spec = s.draw()
s.show()

# %%
from generator import ImageGenerator
file_path = './data/exercise_data'
label_path = './data/Labels.json'
# 实例化ImageGenerator，batch_size = 12
batch1 = ImageGenerator(file_path, label_path, 10, [32, 32, 3], rotation=False, mirroring=False,
                                shuffle=False)
batch1.show()

# %%
#Roation using
batch1 = ImageGenerator(file_path, label_path, 10, [32, 32, 3], rotation=True, mirroring=False,
                                shuffle=False)
batch1.show()

# %%
#mirroring using
batch1 = ImageGenerator(file_path, label_path, 10, [32, 32, 3], rotation=False, mirroring=True,
                                shuffle=False)
batch1.show()

# %%
#shuffler useing
batch1 = ImageGenerator(file_path, label_path, 10, [32, 32, 3], rotation=False, mirroring=False,
                                shuffle=True)
batch1.show()
